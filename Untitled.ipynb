# %%
import pandas as pd

# Load your existing dataset
df = pd.read_csv("paysim_processed_with_scores.csv")

# Reset index and create transaction_id
df = df.reset_index(drop=True)
df.insert(0, "transaction_id", df.index)

# Save updated dataset
df.to_csv("paysim_processed_with_scores_with_txn_id.csv", index=False)

print(" transaction_id added and dataset saved")
# Out:
#  transaction_id added and dataset saved

# %%
df = pd.read_csv("paysim_processed_with_scores_with_txn_id.csv")

# %%
df.head()
# Out:
#    transaction_id  step      amount  oldbalanceOrg  newbalanceOrig  \
# 0               0   278   330218.42       20866.00       351084.42
# 1               1    15    11647.08       30370.00        18722.92
# 2               2    10   152264.21      106589.00       258853.21
# 3               3   403  1551760.63           0.00            0.00
# 4               4   206    78172.30     2921331.58      2999503.88
#
#    oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  balance_delta_org  \
# 0       452419.57       122201.15        0               0         -330218.42
# 1            0.00            0.00        0               0           11647.08
# 2       201303.01        49038.80        0               0         -152264.21
# 3      3198359.45      4750120.08        0               0               0.00
# 4       415821.90       337649.60        0               0          -78172.30
#
#    ...  type_TRANSFER  ml_fraud_score  ml_anomaly_flag  rule_score  \
# ...

# %%
data=df[~df['llm_explanation']]="Not investigated (low risk)"
print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16344\2874284947.py in <module>
# ----> 1 data=df[~df['llm_explanation']]="Not investigated (low risk)"
#       2 print(data)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __invert__(self)
#    1569             return self.copy(deep=False)
#    1570
# -> 1571         new_data = self._mgr.apply(operator.invert)
#    1572         res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    1573         return res.__finalize__(self, method="__invert__")
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     359
#     360             if callable(f):
# --> 361                 applied = b.apply(f, **kwargs)
#     362             else:
#     363                 applied = getattr(b, f)(**kwargs)
#
# ...

# %%
filtered_df = df[df['llm_explanation'] != "Not investigated (low risk)"]
filtered_df.head()
# Out:
#        transaction_id  step       amount  oldbalanceOrg  newbalanceOrig  \
# 1987             1987    16    604655.29    15549053.01      16153708.3
# 2530             2530   375  10001912.39      411395.34             0.0
# 3069             3069   301  17271014.73           0.00             0.0
# 3542             3542   299   2370261.62      560018.88             0.0
# 11754           11754   304   4076906.76           0.00             0.0
#
#        oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 1987      20317906.47     19559832.02        0               0
# 2530      16677560.66     26679473.05        0               0
# 3069      20978054.78     38249069.51        0               0
# 3542      25134366.44     27504628.06        0               0
# 11754     50095110.08     54172016.85        0               0
#
#        balance_delta_org  ...  type_TRANSFER  ml_fraud_score  ml_anomaly_flag  \
# ...

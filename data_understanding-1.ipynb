# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("paysim_sample.csv")
df.head()
# Out:
#    step      type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   278   CASH_IN   330218.42   C632336343       20866.00       351084.42
# 1    15   PAYMENT    11647.08  C1264712553       30370.00        18722.92
# 2    10   CASH_IN   152264.21  C1746846248      106589.00       258853.21
# 3   403  TRANSFER  1551760.63   C333676753           0.00            0.00
# 4   206   CASH_IN    78172.30   C813403091     2921331.58      2999503.88
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0   C834976624       452419.57       122201.15        0               0
# 1   M215391829            0.00            0.00        0               0
# 2  C1607284477       201303.01        49038.80        0               0
# 3  C1564353608      3198359.45      4750120.08        0               0
# 4  C1091768874       415821.90       337649.60        0               0

# %%
df.shape
# Out:
# (150000, 11)

# %%
df.isnull().sum()   #no null values
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df['isFraud'].value_counts() #the dataset is highly imbalanced
# Out:
# isFraud
# 0    149808
# 1       192
# Name: count, dtype: int64

# %%
df['isFraud'].value_counts(normalize=True)*100
# Out:
# isFraud
# 0    99.872
# 1     0.128
# Name: proportion, dtype: float64

# %%
pd.crosstab(df["type"], df["isFraud"])
# Out:
# isFraud       0    1
# type
# CASH_IN   33214    0
# CASH_OUT  52732   83
# DEBIT       928    0
# PAYMENT   50582    0
# TRANSFER  12352  109

# %%
pd.crosstab(df["type"], df["isFraud"], normalize="index") * 100
# Out:
# isFraud            0         1
# type
# CASH_IN   100.000000  0.000000
# CASH_OUT   99.842848  0.157152
# DEBIT     100.000000  0.000000
# PAYMENT   100.000000  0.000000
# TRANSFER   99.125271  0.874729

# %%
df["amount"].describe()
# Out:
# count    1.500000e+05
# mean     1.793068e+05
# std      5.638623e+05
# min      3.300000e-01
# 25%      1.341682e+04
# 50%      7.551588e+04
# 75%      2.081577e+05
# max      3.697390e+07
# Name: amount, dtype: float64

# %%
df[df["isFraud"] == 1]["amount"].describe()
# Out:
# count    1.920000e+02
# mean     1.282890e+06
# std      2.037202e+06
# min      1.510000e+02
# 25%      1.089230e+05
# 50%      4.293507e+05
# 75%      1.421908e+06
# max      1.000000e+07
# Name: amount, dtype: float64
